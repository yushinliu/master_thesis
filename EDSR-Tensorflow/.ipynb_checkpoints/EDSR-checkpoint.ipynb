# %%
#basic packages
import scipy.misc
import random
import numpy as np
import os
import matplotlib.pyplot as plt
# processing bar
from tqdm import tqdm

#import EDSR model
from model_lr_decay import EDSR
from data import load_dataset,crop_center,get_batch,get_test_set
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# # 1. Test using Bicubic

# %%
def PSNR(input,output):
    mse=np.sum((input-output)**2)/(input.shape[0]*input.shape[1]*input.shape[2])
    psnr=20*np.log10(255.0)-10*np.log10(mse)
    print("the psnr is ",psnr)
    return psnr

# %%
train_set,test_set=load_dataset("D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100",100)
train_set
# Out:
# 100
# [('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_84.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_44.bmp',
#   (4, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_31.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_19.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_94.bmp',
#   (2, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_38.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_75.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_87.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_4.bmp',
#   (3, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_9.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_26.bmp',
#   (3, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_35.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_72.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_16.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_54.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_40.bmp',
#   (0, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_41.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_97.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_87.bmp',
#   (2, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_40.bmp',
#   (2, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_52.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_50.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_63.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_80.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_79.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_29.bmp',
#   (0, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_91.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_8.bmp',
#   (2, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_19.bmp',
#   (3, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_31.bmp',
#   (0, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_29.bmp',
#   (1, 6)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_26.bmp',
#   (3, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_8.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_8.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_27.bmp',
#   (3, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_54.bmp',
#   (3, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_18.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_2.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_44.bmp',
#   (0, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_21.bmp',
#   (3, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_44.bmp',
#   (0, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_44.bmp',
#   (2, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_98.bmp',
#   (3, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_15.bmp',
#   (3, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_53.bmp',
#   (3, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_52.bmp',
#   (3, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_28.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_82.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_11.bmp',
#   (3, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_49.bmp',
#   (3, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_99.bmp',
#   (5, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_34.bmp',
#   (3, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_17.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_24.bmp',
#   (2, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_41.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_15.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_15.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_43.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_9.bmp',
#   (2, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_46.bmp',
#   (4, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_99.bmp',
#   (3, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_42.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_99.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_58.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_2.bmp',
#   (3, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_99.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_46.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_97.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_46.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_29.bmp',
#   (3, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_39.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_99.bmp',
#   (4, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_75.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_34.bmp',
#   (3, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_77.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_74.bmp',
#   (4, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_27.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_36.bmp',
#   (6, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_16.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_45.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_98.bmp',
#   (0, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_14.bmp',
#   (2, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_89.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_44.bmp',
#   (2, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_36.bmp',
#   (6, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_78.bmp',
#   (3, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_86.bmp',
#   (2, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_84.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_94.bmp',
#   (3, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_55.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_41.bmp',
#   (0, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_3.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_10.bmp',
#   (4, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_10.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_87.bmp',
#   (2, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_91.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_100.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_99.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_29.bmp',
#   (3, 7)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_41.bmp',
#   (3, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_81.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_55.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_76.bmp',
#   (2, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_35.bmp',
#   (2, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_93.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_65.bmp',
#   (2, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_7.bmp',
#   (2, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_94.bmp',
#   (3, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_19.bmp',
#   (3, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_59.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_78.bmp',
#   (2, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_95.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_52.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_14.bmp',
#   (2, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_62.bmp',
#   (3, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_20.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_74.bmp',
#   (3, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_20.bmp',
#   (2, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_35.bmp',
#   (2, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_7.bmp',
#   (0, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_2.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_16.bmp',
#   (2, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_100.bmp',
#   (0, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_42.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_80.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_86.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_26.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_63.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_26.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_23.bmp',
#   (3, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_14.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_27.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_64.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_34.bmp',
#   (2, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_39.bmp',
#   (3, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_60.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_14.bmp',
#   (3, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_14.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_13.bmp',
#   (2, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_5.bmp',
#   (2, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_15.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_37.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_62.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_8.bmp',
#   (2, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_51.bmp',
#   (2, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_99.bmp',
#   (4, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_9.bmp',
#   (2, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_52.bmp',
#   (2, 6)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_80.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_34.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_14.bmp',
#   (0, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_1.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_97.bmp',
#   (2, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_43.bmp',
#   (0, 6)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_81.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_33.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_10.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_41.bmp',
#   (2, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_46.bmp',
#   (4, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_2.bmp',
#   (3, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_26.bmp',
#   (4, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_99.bmp',
#   (0, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_37.bmp',
#   (2, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_26.bmp',
#   (0, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_8.bmp',
#   (2, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_50.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_53.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_38.bmp',
#   (0, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_51.bmp',
#   (1, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_12.bmp',
#   (2, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_61.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_26.bmp',
#   (2, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_28.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_3.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_51.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_72.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_72.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_8.bmp',
#   (3, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_62.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_34.bmp',
#   (2, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_34.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_36.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_51.bmp',
#   (3, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_1.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_66.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_38.bmp',
#   (0, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_9.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_74.bmp',
#   (1, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_43.bmp',
#   (5, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_74.bmp',
#   (4, 6)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_26.bmp',
#   (2, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_53.bmp',
#   (3, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_28.bmp',
#   (0, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_100.bmp',
#   (2, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_94.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_23.bmp',
#   (1, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_77.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_94.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_73.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_80.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_43.bmp',
#   (5, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_76.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_6.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_31.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_14.bmp',
#   (0, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_24.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_96.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_29.bmp',
#   (0, 8)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_31.bmp',
#   (2, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_86.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_22.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_48.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_39.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_14.bmp',
#   (3, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_63.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_22.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_64.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_49.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_59.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_38.bmp',
#   (2, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_51.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_13.bmp',
#   (3, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_14.bmp',
#   (3, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_35.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_30.bmp',
#   (2, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_49.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_25.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_26.bmp',
#   (5, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_87.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_5.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_35.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_12.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_15.bmp',
#   (3, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_46.bmp',
#   (4, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_34.bmp',
#   (1, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_74.bmp',
#   (0, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_39.bmp',
#   (1, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_71.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_14.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_88.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_99.bmp',
#   (5, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_24.bmp',
#   (2, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_4.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_28.bmp',
#   (2, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_86.bmp',
#   (2, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_36.bmp',
#   (3, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_51.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_23.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_86.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_68.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_52.bmp',
#   (4, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_37.bmp',
#   (3, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_62.bmp',
#   (3, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_95.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_82.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_41.bmp',
#   (2, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_65.bmp',
#   (2, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_41.bmp',
#   (1, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_64.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_45.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_53.bmp',
#   (4, 6)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_5.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_41.bmp',
#   (2, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_41.bmp',
#   (4, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_46.bmp',
#   (0, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_41.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_36.bmp',
#   (2, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_26.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_100.bmp',
#   (2, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_32.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_19.bmp',
#   (0, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_21.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_21.bmp',
#   (3, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_16.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_53.bmp',
#   (4, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_75.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_25.bmp',
#   (2, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_74.bmp',
#   (2, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_29.bmp',
#   (2, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_29.bmp',
#   (0, 6)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_17.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_40.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_35.bmp',
#   (3, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_23.bmp',
#   (2, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_48.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_34.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_54.bmp',
#   (3, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_59.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_29.bmp',
#   (1, 8)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_99.bmp',
#   (0, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_44.bmp',
#   (4, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_52.bmp',
#   (1, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_44.bmp',
#   (0, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_16.bmp',
#   (3, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_89.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_33.bmp',
#   (2, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_36.bmp',
#   (1, 6)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_5.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_90.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_34.bmp',
#   (3, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_100.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_78.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_76.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_38.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_46.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_81.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_34.bmp',
#   (4, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_34.bmp',
#   (2, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_2.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_34.bmp',
#   (2, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_70.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_74.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_35.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_74.bmp',
#   (3, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_6.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_36.bmp',
#   (0, 6)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_36.bmp',
#   (0, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_28.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_42.bmp',
#   (2, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_43.bmp',
#   (2, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_24.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_65.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_20.bmp',
#   (3, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_30.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_27.bmp',
#   (0, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_74.bmp',
#   (3, 6)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_52.bmp',
#   (0, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_43.bmp',
#   (4, 6)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_82.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_36.bmp',
#   (5, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_52.bmp',
#   (4, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_36.bmp',
#   (4, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_74.bmp',
#   (3, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_65.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_14.bmp',
#   (2, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_68.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_8.bmp',
#   (3, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_15.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_94.bmp',
#   (0, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_49.bmp',
#   (3, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_84.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_36.bmp',
#   (5, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_44.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_89.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_98.bmp',
#   (3, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_30.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_36.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_7.bmp',
#   (2, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_54.bmp',
#   (2, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_87.bmp',
#   (1, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_29.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_34.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_36.bmp',
#   (1, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_68.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_74.bmp',
#   (0, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_43.bmp',
#   (3, 6)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_6.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_8.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_16.bmp',
#   (3, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_39.bmp',
#   (3, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_97.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_45.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_86.bmp',
#   (0, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_53.bmp',
#   (3, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_15.bmp',
#   (3, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_39.bmp',
#   (3, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_53.bmp',
#   (0, 6)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_10.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_7.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_39.bmp',
#   (2, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_98.bmp',
#   (3, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_88.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_29.bmp',
#   (2, 6)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_43.bmp',
#   (2, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_36.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_60.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_27.bmp',
#   (2, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_20.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_10.bmp',
#   (2, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_75.bmp',
#   (3, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_12.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_41.bmp',
#   (0, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_17.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_94.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_19.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_46.bmp',
#   (3, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_21.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_23.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_42.bmp',
#   (2, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_33.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_38.bmp',
#   (3, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_86.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_10.bmp',
#   (4, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_10.bmp',
#   (3, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_43.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_20.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_31.bmp',
#   (2, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_14.bmp',
#   (1, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_97.bmp',
#   (0, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_100.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_8.bmp',
#   (0, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_53.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_49.bmp',
#   (3, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_13.bmp',
#   (3, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_55.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_78.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_84.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_54.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_43.bmp',
#   (4, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_39.bmp',
#   (0, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_52.bmp',
#   (3, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_9.bmp',
#   (2, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_44.bmp',
#   (2, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_8.bmp',
#   (3, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_98.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_53.bmp',
#   (2, 6)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_28.bmp',
#   (2, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_36.bmp',
#   (3, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_31.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_44.bmp',
#   (1, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_18.bmp',
#   (2, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_12.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_22.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_47.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_47.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_23.bmp',
#   (3, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_7.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_29.bmp',
#   (3, 6)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_74.bmp',
#   (2, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_19.bmp',
#   (3, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_24.bmp',
#   (2, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_63.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_87.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_10.bmp',
#   (4, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_39.bmp',
#   (4, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_88.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_39.bmp',
#   (4, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_38.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_24.bmp',
#   (0, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_11.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_15.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_36.bmp',
#   (2, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_81.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_82.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_10.bmp',
#   (2, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_83.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_54.bmp',
#   (3, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_7.bmp',
#   (3, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_76.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_23.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_97.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_99.bmp',
#   (4, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_92.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_29.bmp',
#   (3, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_52.bmp',
#   (3, 6)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_91.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_52.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_87.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_44.bmp',
#   (4, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_2.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_25.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_52.bmp',
#   (0, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_26.bmp',
#   (6, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_34.bmp',
#   (3, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_10.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_10.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_11.bmp',
#   (2, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_8.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_62.bmp',
#   (2, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_14.bmp',
#   (3, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_35.bmp',
#   (1, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_27.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_39.bmp',
#   (5, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_33.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_2.bmp',
#   (3, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_68.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_36.bmp',
#   (5, 6)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_75.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_65.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_99.bmp',
#   (6, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_7.bmp',
#   (0, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_5.bmp',
#   (3, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_43.bmp',
#   (5, 6)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_43.bmp',
#   (3, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_92.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_21.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_4.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_39.bmp',
#   (6, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_89.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_39.bmp',
#   (6, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_60.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_74.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_28.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_44.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_46.bmp',
#   (3, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_71.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_78.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_95.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_10.bmp',
#   (3, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_12.bmp',
#   (0, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_45.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_19.bmp',
#   (2, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_14.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_43.bmp',
#   (4, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_26.bmp',
#   (6, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_96.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_8.bmp',
#   (1, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_14.bmp',
#   (2, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_43.bmp',
#   (0, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_43.bmp',
#   (3, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_47.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_14.bmp',
#   (4, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_5.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_54.bmp',
#   (3, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_26.bmp',
#   (4, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_29.bmp',
#   (0, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_81.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_39.bmp',
#   (2, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_55.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_67.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_36.bmp',
#   (2, 6)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_88.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_23.bmp',
#   (2, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_52.bmp',
#   (2, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_5.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_63.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_98.bmp',
#   (3, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_43.bmp',
#   (1, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_62.bmp',
#   (4, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_13.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_48.bmp',
#   (2, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_43.bmp',
#   (0, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_49.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_32.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_54.bmp',
#   (0, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_30.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_48.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_22.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_96.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_9.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_20.bmp',
#   (2, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_27.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_98.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_41.bmp',
#   (3, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_34.bmp',
#   (4, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_85.bmp',
# ...
#   (5, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_44.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_12.bmp',
#   (3, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_43.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_38.bmp',
#   (2, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_39.bmp',
#   (5, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_86.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_30.bmp',
#   (0, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_53.bmp',
#   (0, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_56.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_29.bmp',
#   (3, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_65.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_75.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_36.bmp',
#   (2, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_29.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_78.bmp',
#   (3, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_36.bmp',
#   (3, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_64.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_39.bmp',
#   (5, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_44.bmp',
#   (1, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_18.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_43.bmp',
#   (0, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_49.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_53.bmp',
#   (3, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_49.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_84.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_91.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_98.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_2.bmp',
#   (0, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_53.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_53.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_43.bmp',
#   (3, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_39.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_7.bmp',
#   (3, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_49.bmp',
#   (0, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_89.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_37.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_52.bmp',
#   (4, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_5.bmp',
#   (2, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_52.bmp',
#   (1, 6)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_40.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_14.bmp',
#   (3, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_68.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_38.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_82.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_53.bmp',
#   (4, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_8.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_92.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_36.bmp',
#   (4, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_26.bmp',
#   (3, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_28.bmp',
#   (2, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_33.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_63.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_32.bmp',
#   (2, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_52.bmp',
#   (2, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_1.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_72.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_48.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_76.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_80.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_75.bmp',
#   (0, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_35.bmp',
#   (3, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_32.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_46.bmp',
#   (3, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_38.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_64.bmp',
#   (2, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_94.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_79.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_16.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_54.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_43.bmp',
#   (3, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_44.bmp',
#   (3, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_41.bmp',
#   (2, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_26.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_46.bmp',
#   (2, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_10.bmp',
#   (1, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_44.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_37.bmp',
#   (3, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_49.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_58.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_14.bmp',
#   (2, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_62.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_99.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_29.bmp',
#   (2, 8)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_52.bmp',
#   (2, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_74.bmp',
#   (4, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_44.bmp',
#   (4, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_15.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_31.bmp',
#   (0, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_35.bmp',
#   (0, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_28.bmp',
#   (3, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_86.bmp',
#   (0, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_18.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_46.bmp',
#   (2, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_78.bmp',
#   (2, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_41.bmp',
#   (4, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_52.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_52.bmp',
#   (0, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_38.bmp',
#   (3, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_26.bmp',
#   (4, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_24.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_7.bmp',
#   (3, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_36.bmp',
#   (5, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_16.bmp',
#   (3, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_25.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_95.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_2.bmp',
#   (2, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_23.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_22.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_52.bmp',
#   (2, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_39.bmp',
#   (6, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_100.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_7.bmp',
#   (2, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_38.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_94.bmp',
#   (2, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_54.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_19.bmp',
#   (2, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_99.bmp',
#   (3, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_37.bmp',
#   (1, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_95.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_29.bmp',
#   (2, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_23.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_24.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_26.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_41.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_80.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_30.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_9.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_39.bmp',
#   (1, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_31.bmp',
#   (2, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_14.bmp',
#   (4, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_2.bmp',
#   (3, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_63.bmp',
#   (2, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_39.bmp',
#   (5, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_99.bmp',
#   (6, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_53.bmp',
#   (4, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_27.bmp',
#   (0, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_86.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_3.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_62.bmp',
#   (0, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_46.bmp',
#   (4, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_29.bmp',
#   (2, 7)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_21.bmp',
#   (3, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_32.bmp',
#   (3, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_13.bmp',
#   (2, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_43.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_53.bmp',
#   (3, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_41.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_73.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_94.bmp',
#   (1, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_46.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_86.bmp',
#   (2, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_13.bmp',
#   (2, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_52.bmp',
#   (3, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_23.bmp',
#   (3, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_14.bmp',
#   (1, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_39.bmp',
#   (6, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_23.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_6.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_13.bmp',
#   (3, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_36.bmp',
#   (2, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_63.bmp',
#   (2, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_74.bmp',
#   (2, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_36.bmp',
#   (5, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_17.bmp',
#   (3, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_50.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_36.bmp',
#   (1, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_29.bmp',
#   (3, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_28.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_4.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_43.bmp',
#   (2, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_3.bmp',
#   (0, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_41.bmp',
#   (3, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_53.bmp',
#   (3, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_12.bmp',
#   (0, 0)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_98.bmp',
#   (2, 4)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_44.bmp',
#   (2, 5)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_43.bmp',
#   (2, 6)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_37.bmp',
#   (3, 3)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_94.bmp',
#   (1, 2)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_75.bmp',
#   (2, 1)),
#  ('D://LAB//master_thesis//EDSR-Tensorflow//dataset//General-100/im_6.bmp',
#   (0, 2))]

# %%
len(test_set)
# Out:
# 100

# %%
img=scipy.misc.imread(train_set[0][0])

# %%
plt.imshow(img)
plt.show()

# %%
#downsampling scale is 2: 100/2 =50 
arg=(10,100,50)
x,y,batch_size=get_batch(*arg)
# Out:
# 1.0

# %%
x[0].shape
# Out:
# (50, 50, 3)

# %%
y_out=scipy.misc.imresize(x[0],(100,100),interp='bicubic')

# %%
y[0].shape
# Out:
# (100, 100, 3)

# %%
#input batch of train data
plt.imshow(x[0])
plt.show()

# %%
# target data
plt.imshow(y[0])
plt.show()

# %%
#bicubic data
plt.imshow(y_out)
plt.show()

# %%
PSNR(y_out,y[0])
# Out:
# the psnr is  37.5900124726
# 37.59001247257406

# %% [markdown]
# # 1. Train the one batch on one nature image

# %%
network = EDSR(50,32,256,2)
# Out:
# Building EDSR...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-815d3d330f2f> in <module>()
# ----> 1 network = EDSR(50,32,256,2)
#
# D:\LAB\master_thesis\EDSR-Tensorflow\model_lr_decay.py in __init__(self, img_size, num_layers, feature_size, scale, output_channels)
#     116
#     117                 #Tensorflow graph setup... session, saver, etc.
# --> 118                 self.sess = tf.Session()
#     119                 self.saver = tf.train.Saver()
#     120                 print("Done building!")
#
# D:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in __init__(self, target, graph, config)
#    1480
#    1481     """
# -> 1482     super(Session, self).__init__(target, graph, config=config)
#    1483     # NOTE(mrry): Create these on first `__enter__` to avoid a reference cycle.
#    1484     self._default_graph_context_manager = None
#
# D:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in __init__(self, target, graph, config)
#     620           # pylint: enable=protected-access
#     621         else:
# --> 622           self._session = tf_session.TF_NewDeprecatedSession(opts, status)
#     623     finally:
#     624       tf_session.TF_DeleteSessionOptions(opts)
#
# KeyboardInterrupt:

# %%
network.train(X_train=x,y_train=y)

# %%
(x-np.mean(x)).shape

# %% [markdown]
# # 2. Train the mini-batch on nature image

# %%
#network = EDSR(50,32,256,2)
network = EDSR(50,16,64,2) #one base line
# Out:
# Building EDSR...
# Done building!

# %%
network.set_data_fn(get_batch,(10,100,50),get_test_set,(100,50)) # batch size is 10

# %%
network.train()
# Out:
# Begin training...
# D:\ProgramData\Anaconda3\lib\site-packages\scipy\misc\pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# D:\ProgramData\Anaconda3\lib\site-packages\scipy\misc\pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
#  the time cost is 0.000033 minute------------------]0.03%
#  the time cost is 0.890837 minute------------------]3.37%
#  the time cost is 1.746389 minute------------------]6.70%
#  the time cost is 2.607067 minute------------------]10.03%
#  the time cost is 3.468523 minute------------------]13.37%
#  the time cost is 4.327010 minute------------------]16.70%
#  the time cost is 5.188255 minute------------------]20.03%
#  the time cost is 6.049751 minute------------------]23.37%
#  the time cost is 6.914634 minute------------------]26.70%
#  the time cost is 7.780168 minute------------------]30.03%
#  the time cost is 8.646306 minute------------------]33.37%
#  the time cost is 9.506322 minute------------------]36.70%
#  the time cost is 10.380351 minute-----------------]40.03%
#  the time cost is 11.259633 minute-----------------]43.37%
#  the time cost is 12.146065 minute-----------------]46.70%
#  the time cost is 13.032840 minute-----------------]50.03%
#  the time cost is 13.913296 minute-----------------]53.37%
#  the time cost is 14.791066 minute-----------------]56.70%
#  the time cost is 15.664481 minute-----------------]60.03%
#  the time cost is 16.540966 minute-----------------]63.37%
#  the time cost is 17.410840 minute-----------------]66.70%
#  the time cost is 18.285772 minute>>---------------]70.03%
#  the time cost is 19.156298 minute>>>--------------]73.37%
#  the time cost is 20.023930 minute>>>>>------------]76.70%
#  the time cost is 20.900826 minute>>>>>>>----------]80.03%
#  the time cost is 21.766010 minute>>>>>>>>---------]83.37%
#  the time cost is 22.635210 minute>>>>>>>>>>-------]86.70%
#  the time cost is 23.502608 minute>>>>>>>>>>>>-----]90.03%
#  the time cost is 24.375900 minute>>>>>>>>>>>>>----]93.37%
#  the time cost is 25.252194 minute>>>>>>>>>>>>>>>--]96.70%
# done>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>]100.00%
# Saving...
# Saved!

# %% [markdown]
# # 3. Compare with bicubic method

# %%
def plot_img(dir):
    img=scipy.misc.imread("D://LAB//masterthesis_result//nature_image//results//"+str(dir))
    plt.imshow(img)
    plt.axis("off")
    plt.show()
    return img

# %%
input_img=plot_img("input_1.png")

# %%
target_img=plot_img("target_1.png")

# %%
bicubic_img=scipy.misc.imresize(input_img,(100,100),interp='bicubic')
plt.imshow(bicubic_img)
plt.axis("off")
plt.show()
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\scipy\misc\pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# D:\ProgramData\Anaconda3\lib\site-packages\scipy\misc\pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):

# %%
output_img=plot_img("output_1.png")

# %%
PSNR(bicubic_img,target_img)
# Out:
# the psnr is  29.423794186041306
# 29.423794186041306

# %%
PSNR(output_img,target_img)
# Out:
# the psnr is  31.123671274142026
# 31.123671274142026
